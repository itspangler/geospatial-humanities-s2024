# %%
import json
import requests
import pandas as pd

# query = requests.get("https://www.digitalcommonwealth.org/search.json?f%5Bgenre_basic_ssim%5D%5B%5D=Cards&f%5Bsubject_geographic_sim%5D%5B%5D=United+States&page=1&per_page=100")

query=requests.get("https://www.digitalcommonwealth.org/search.json?f%5Bgenre_basic_ssim%5D%5B%5D=Cards&f%5Bsubject_facet_ssim%5D%5B%5D=Cities+%26+towns&f%5Bsubject_facet_ssim%5D%5B%5D=Beaches&f%5Bsubject_geographic_sim%5D%5B%5D=United+States&per_page=20")
response = json.dumps(query.json(), indent=2)
data = json.loads(response)

this = (data['links']['self'])
next = (data['links']['next'])
final = (data['links']['last'])

# %%
# set pandas dataframe column names

columnNames=[]
for record in data['data']:    
    for field in record['attributes']:
        if field not in columnNames:
            columnNames.append(field)

out=pd.DataFrame(columns=columnNames)

# %%
# walk through search results in JSON format using DC JSON API

while True:

    # get THIS page and set desired metadata fields

    print("This page: "+this)
    print("Next page: "+next)
    print("Last page: "+final)
    for record in data['data']:
        print(f"Processing object ID: {id}")
        id=record['id']
        q=requests.get(f'https://www.digitalcommonwealth.org/search/{id}.json')
        resp=json.dumps(q.json())
        d=json.loads(resp)
        i=d['data']['attributes']

        # print desired THIS metadata fields

        df=pd.DataFrame([i])
        out=pd.concat([out, df])

    # get NEXT page

    query=requests.get(next)
    response=json.dumps(query.json(), indent=2)
    data = json.loads(response)
    
    # reset all THIS variables to NEXT
    # but save & break if you're at the end

    if this == final:
        out.to_csv("out.csv")
        break
    else:
        this = (data['links']['self'])
        if len(data['links']) > 3:
            next = (data['links']['next'])
        final = (data['links']['last'])
    
    out.to_csv("out.csv")
# Out:
# This page: https://www.digitalcommonwealth.org/search.json?f%5Bgenre_basic_ssim%5D%5B%5D=Cards&f%5Bsubject_facet_ssim%5D%5B%5D=Cities+%26+towns&f%5Bsubject_facet_ssim%5D%5B%5D=Beaches&f%5Bsubject_geographic_sim%5D%5B%5D=United+States&per_page=20
# Next page: https://www.digitalcommonwealth.org/search.json?f%5Bgenre_basic_ssim%5D%5B%5D=Cards&f%5Bsubject_facet_ssim%5D%5B%5D=Cities+%26+towns&f%5Bsubject_facet_ssim%5D%5B%5D=Beaches&f%5Bsubject_geographic_sim%5D%5B%5D=United+States&page=2&per_page=20
# Last page: https://www.digitalcommonwealth.org/search.json?f%5Bgenre_basic_ssim%5D%5B%5D=Cards&f%5Bsubject_facet_ssim%5D%5B%5D=Cities+%26+towns&f%5Bsubject_facet_ssim%5D%5B%5D=Beaches&f%5Bsubject_geographic_sim%5D%5B%5D=United+States&page=7&per_page=20
# Processing object ID: <built-in function id>
# Processing object ID: commonwealth:mg74qt85r
# Processing object ID: commonwealth:mg74qt879
# Processing object ID: commonwealth:w3763v256
# Processing object ID: commonwealth:pk02cg903
# Processing object ID: commonwealth:x920gg94b
# Processing object ID: commonwealth:mg74qq19j
# Processing object ID: commonwealth:mg74qv026
# Processing object ID: commonwealth:6d570q609
# Processing object ID: commonwealth:pk02ch18k
# Processing object ID: commonwealth:6d570m39f
# Processing object ID: commonwealth:6d570m406
# Processing object ID: commonwealth:6d570t463
# Processing object ID: commonwealth:5m60r123b
# Processing object ID: commonwealth:mg74qq170
# Processing object ID: commonwealth:mg74qq35x
# Processing object ID: commonwealth:mg74qq37g
# Processing object ID: commonwealth:pz50gz20t
# Processing object ID: commonwealth:ff365726x
# Processing object ID: commonwealth:6d570t242
# This page: https://www.digitalcommonwealth.org/search.json?f%5Bgenre_basic_ssim%5D%5B%5D=Cards&f%5Bsubject_facet_ssim%5D%5B%5D=Cities+%26+towns&f%5Bsubject_facet_ssim%5D%5B%5D=Beaches&f%5Bsubject_geographic_sim%5D%5B%5D=United+States&page=2&per_page=20
# Next page: https://www.digitalcommonwealth.org/search.json?f%5Bgenre_basic_ssim%5D%5B%5D=Cards&f%5Bsubject_facet_ssim%5D%5B%5D=Cities+%26+towns&f%5Bsubject_facet_ssim%5D%5B%5D=Beaches&f%5Bsubject_geographic_sim%5D%5B%5D=United+States&page=3&per_page=20
# Last page: https://www.digitalcommonwealth.org/search.json?f%5Bgenre_basic_ssim%5D%5B%5D=Cards&f%5Bsubject_facet_ssim%5D%5B%5D=Cities+%26+towns&f%5Bsubject_facet_ssim%5D%5B%5D=Beaches&f%5Bsubject_geographic_sim%5D%5B%5D=United+States&page=7&per_page=20
# Processing object ID: commonwealth:6d570t27w
# Processing object ID: commonwealth:mg74qp81t
# Processing object ID: commonwealth:mg74qp83c
# Processing object ID: commonwealth:pk02cf826
# Processing object ID: commonwealth:0k225t79n
# Processing object ID: commonwealth:6d570q61k
# Processing object ID: commonwealth:mg74qr639
# Processing object ID: commonwealth:mg74qq25p
# Processing object ID: commonwealth:mg74qq277
# Processing object ID: commonwealth:x920gf12n
# Processing object ID: commonwealth:1257b786d
# Processing object ID: commonwealth:0p097125w
# Processing object ID: commonwealth:2n49tj064
# Processing object ID: commonwealth:w3763p67p
# Processing object ID: commonwealth:mk61rz314
# Processing object ID: commonwealth:mg74qq95c
# Processing object ID: commonwealth:5m60r3241
# Processing object ID: commonwealth:5m60r322g
# Processing object ID: commonwealth:mg74qp41v
# Processing object ID: commonwealth:mg74qp43d
# This page: https://www.digitalcommonwealth.org/search.json?f%5Bgenre_basic_ssim%5D%5B%5D=Cards&f%5Bsubject_facet_ssim%5D%5B%5D=Cities+%26+towns&f%5Bsubject_facet_ssim%5D%5B%5D=Beaches&f%5Bsubject_geographic_sim%5D%5B%5D=United+States&page=3&per_page=20
# Next page: https://www.digitalcommonwealth.org/search.json?f%5Bgenre_basic_ssim%5D%5B%5D=Cards&f%5Bsubject_facet_ssim%5D%5B%5D=Cities+%26+towns&f%5Bsubject_facet_ssim%5D%5B%5D=Beaches&f%5Bsubject_geographic_sim%5D%5B%5D=United+States&page=4&per_page=20
# Last page: https://www.digitalcommonwealth.org/search.json?f%5Bgenre_basic_ssim%5D%5B%5D=Cards&f%5Bsubject_facet_ssim%5D%5B%5D=Cities+%26+towns&f%5Bsubject_facet_ssim%5D%5B%5D=Beaches&f%5Bsubject_geographic_sim%5D%5B%5D=United+States&page=7&per_page=20
# Processing object ID: commonwealth:5m60r318w
# Processing object ID: commonwealth:2n49th849
# Processing object ID: commonwealth:zk51vj347
# Processing object ID: commonwealth:5m60r407k
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-279d101e68b5> in <module>
#      11         print(f"Processing object ID: {id}")
#      12         id=record['id']
# ---> 13         q=requests.get(f'https://www.digitalcommonwealth.org/search/{id}.json')
#      14         resp=json.dumps(q.json())
#      15         d=json.loads(resp)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     351     def connect(self):
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#     355         tls_in_tls = False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     167
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71         )
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#      75         sock = None
#
# ~/opt/anaconda3/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     916     # and socket type values to enum constants.
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#     920         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:
